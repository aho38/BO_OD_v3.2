# %%
from utils.datasets import create_dataloader
from utils.general import coco80_to_coco91_class, check_dataset, check_file, check_img_size, check_requirements, \
    box_iou, non_max_suppression, scale_coords, xyxy2xywh, xywh2xyxy, set_logging, increment_path, colorstr
from tqdm import tqdm
from pathlib import Path
import json

# %%
# !pwd
# Out:
# /Users/alexho/Dropbox/LLNL/2021_summer/bayesian/projects/object_detection/BO_OD_v3.2

# %%
f = open('../cluster_results/runs/vanish/exp/yolov5s_predictions.json')
data = json.load(f)

# %%
data[0]
# Out:
# {'image_id': 298251,
#  'category_id': 24,
#  'bbox': [69.982, 90.23, 66.219, 43.763],
#  'score': 0.90057}

# %%
dataloader = create_dataloader('data/coco/val2017.txt', 640, 1, 32, False, pad=0.5, rect=True,
                                       prefix=colorstr(f'vsl: '))[0]

s = ('%20s' + '%11s' * 6) % ('Class', 'Images', 'Labels', 'P', 'R', 'mAP@.5', 'mAP@.5:.95')
for batch_i, (img, targets, paths, shapes) in enumerate(tqdm(dataloader, desc=s)):
    img_id = paths[0].split('/')[-1].split('.')[0].lstrip('0')
    box_ls = []
    
    for i, box_i in enumerate(data):
        if box_i['image_id'] == int(img_id):
            box_ls.append(box_i)
        
        if not len(box_ls):
            continue
        
        same_box_ls = [box_i]
        for j, box_j in enumerate(data):
            if i != j:
                if box_i['bbox'] == box_j['bbox']:
                    same_box_ls.append(box_j)
                    
            max([])
   
        
    
#     for box_i in data:
#         if box_i['image_id'] == 298251:
#             print('yes2')
#     for box_i in data:
#         print(box_i['image_id'])
#         print(type(box_i['image_id']))
#     for box_i in data:
#         if box_i['image_id'] == int(img_id):
#             box_ls.append[box_i]
#             print('yes')
# Out:
# vsl: Scanning 'data/coco/val2017.cache' images and labels... 4952 found, 48 missing, 0 empty, 0 corrupted: 100%|██████████| 5000/5000 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/5000 [00:00<?, ?it/s]
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# ...

# %%
x = [1, 2, 3, 4]
argmax(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-5a546d3cd2ad> in <module>
#       1 x = [1, 2, 3, 4]
# ----> 2 argmax(x)
#
# NameError: name 'argmax' is not defined

# %%
p = []
if not p:
    print('hi')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-b24ca86fa336> in <module>
#       1 p = []
# ----> 2 if p is empty:
#       3     print('hi')
#
# NameError: name 'empty' is not defined
